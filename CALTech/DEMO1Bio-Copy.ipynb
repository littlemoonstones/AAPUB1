# %% [markdown]
# ##  Tutorial Ob:
# > URL  http://www.rpgroup.caltech.edu/ibdm_cbbtn/code/t0b_jupyter_notebooks.html

# %% [markdown]
# ### ME2002- Memo
# > date: 2019-Mar-21

# %% [markdown]
# ### Tutorial 0b: Using Jupyter Notebooks and Jupyter Lab

# %%
### TASK1 1 -- testing numpy, matplotlib and seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
### In order for plots to render within the notebook, you must tell Python to display these plots inline. 

# To do so, we can simply type the following.

# %%
# %matplotlib inline

# %%
# Plot one of Griffin's favorite functions.
x = np.linspace(-np.pi, np.pi, 500)
y = np.sin(2 * np.sin(2 * np.sin(2 * x)))

# Generate the plot.
plt.plot(x, y)
plt.xlabel(r'$x$', fontsize=16)
plt.ylabel(r'$y$', fontsize=16)

# Don't worry about this syntax for now.
_ = plt.xticks([-np.pi, 0, np.pi], ['$-\pi$', '0', '$\pi$'], fontsize=15)

# %% [markdown]
# ### Well Done --Task 1

# %%
#  Reflect -- Fill in  Your Response  Here

# %% [markdown]
# ### TODO:  use (shift-Tab) for the following plt.plot to tell you Details info. for that method :: plot(...)

# %%
plt.plot([10,20,35, 49, 50, 55, 59])

# %%
plt.show()

# %%
# ?plt

# %%
plt.plot([10,20,35, 49, 50, 55, 90], 'ro')
